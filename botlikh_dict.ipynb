# %%
import pandas as pd

# %%
full_df = pd.read_csv('data/andic_dicts.csv')
# Out:
# c:\users\anastasia\appdata\local\programs\python\python38\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (10,15,16) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
botl_df = full_df.loc[full_df['glottocode'] == 'botl1242']
botl_df.rename(columns={'lemma ': 'lemma'}, inplace=True)
# Out:
# c:\users\anastasia\appdata\local\programs\python\python38\lib\site-packages\pandas\core\frame.py:4300: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
botl_df
# Out:
#            lang  id_word  id_meaning     id  \
# 32857  botl1242        1           1  32858
# 32858       NaN        2           1  32859
# 32859       NaN        2           2  32860
# 32860       NaN        2           3  32861
# 32861       NaN        2           4  32862
# ...         ...      ...         ...    ...
# 52532       NaN    15283           1  52533
# 52533       NaN    15284           1  52534
# 52534       NaN    15284           1  52535
# 52535       NaN    15285           1  52536
# 52536       NaN    15285           1  52537
#
#                                    lemma  \
# 32857                               а:хх
# 32858                           аᴴгь/а́й
# 32859                           аᴴгь/а́й
# 32860                           аᴴгь/а́й
# 32861                           аᴴгь/а́й
# ...                                  ...
# 52532                         эшту́лъила
# 52533  эшубхва́да заманалъи́ку белълъа́б
# 52534  эшубхва́да заманалъи́ку белълъа́б
# 52535                             эъе́чу
# 52536                             эъе́чу
#
#                                                      ipa morphology  bor  \
# 32857                                              aː-χː        NaN  NaN
# 32858                                          ã-h-a`-j        NaN  NaN
# 32859                                          ã-h-a`-j        NaN  NaN
# 32860                                          ã-h-a`-j        NaN  NaN
# 32861                                          ã-h-a`-j        NaN  NaN
# ...                                                  ...        ...  ...
# 52532                                   e-ʃ-t-u`-ɬ-i-l-a        NaN  NaN
# 52533  e-ʃ-u-b-χ-w-a`-d-a- -z-a-m-a-n-a-ɬ-i`-k-u- -b-...        NaN  NaN
# 52534  e-ʃ-u-b-χ-w-a`-d-a- -z-a-m-a-n-a-ɬ-i`-k-u- -b-...        NaN  NaN
# 52535                                        e-ʔ-e`-tʃ-u        NaN  NaN
# 52536                                        e-ʔ-e`-tʃ-u        NaN  NaN
#
#           annotator   pos concepticon            meaning_ru  \
# 32857  George Moroz  intj         NaN               баю-бай
# 32858  George Moroz  verb         NaN              сообщать
# 32859  George Moroz  verb         NaN             объявлять
# 32860  George Moroz  verb         NaN              нанимать
# 32861  George Moroz  verb         NaN         предупреждать
# ...             ...   ...         ...                   ...
# 52532  George Moroz   NaN         NaN                 каков
# 52533           NaN   NaN         NaN  с некоторого времени
# 52534           NaN   NaN         NaN  с некоторого времени
# 52535           NaN  noun         NaN                 петух
# 52536           NaN  noun         NaN                 петух
#
#                                               definition glottocode  \
# 32857                                            баю-бай   botl1242
# 32858  понуд. от аᴴгьи; 1) сообщать, доводить до свед...   botl1242
# 32859  понуд. от аᴴгьи; 1) сообщать, доводить до свед...   botl1242
# 32860  понуд. от аᴴгьи; 1) сообщать, доводить до свед...   botl1242
# 32861  понуд. от аᴴгьи; 1) сообщать, доводить до свед...   botl1242
# ...                                                  ...        ...
# 52532                                              каков   botl1242
# 52533                               с некоторого времени   botl1242
# 52534                               с некоторого времени   botl1242
# 52535  мн. -абалъи, рп. -лъи петух; рухьу́лъи эъе́чу ...   botl1242
# 52536  мн. -абалъи, рп. -лъи петух; рухьу́лъи эъе́чу ...   botl1242
#
#                   reference comments borrowing_source_word  \
# 32857  Saidova, Abusov 2012      NaN                   NaN
# 32858  Saidova, Abusov 2012      NaN                   NaN
# 32859  Saidova, Abusov 2012      NaN                   NaN
# 32860  Saidova, Abusov 2012      NaN                   NaN
# 32861  Saidova, Abusov 2012      NaN                   NaN
# ...                     ...      ...                   ...
# 52532         Alekseev 2006      NaN                   NaN
# 52533         Alekseev 2006      NaN                   NaN
# 52534         Alekseev 2006      NaN                   NaN
# 52535         Alekseev 2006      NaN                   NaN
# 52536         Alekseev 2006      NaN                   NaN
#
#        borrowing_source_comment  source
# 32857                       NaN     NaN
# 32858                       NaN     NaN
# 32859                       NaN     NaN
# 32860                       NaN     NaN
# 32861                       NaN     NaN
# ...                         ...     ...
# 52532                       NaN     NaN
# 52533                       NaN     NaN
# 52534                       NaN     NaN
# 52535                       NaN     NaN
# 52536                       NaN     NaN
#
# [19680 rows x 19 columns]

# %%
df = botl_df[['id_word', 'id_meaning', 'lemma', 'bor']]

# %%
def ipaing(text):
    text = text.replace('=', '')
    text = text.replace('-', '')
    text = text.replace('/', '')
    text = text.replace('\\', '')
    text = text.replace('́', '')
    text = text.replace(':', 'ː')
    text = text.replace('(', '')
    text = text.replace(')', '')
    text = text.replace('?', '')
    text = text.replace('–', '')
    text = text.replace('!', '')
    
    text = text.replace('аːᴴ', '-ãː')
    text = text.replace('аᴴ', '-ã')
    text = text.replace('а', '-a')
    
    text = text.replace('б', '-b')
    
    text = text.replace('в', '-w')
    
    text = text.replace('гъ', '-ʁ')
    text = text.replace('гI', '-ʕ')
    text = text.replace('гь', '-h')
    text = text.replace('г', '-ɡ')
    
    text = text.replace('дж', '-d͡ʒ')
    text = text.replace('д', '-d')
    
    text = text.replace('еᴴ', '-ẽ')
    text = text.replace('е', '-e')
    
    text = text.replace('ж', '-ʒ')
    
    text = text.replace('з', '-z')
    
    text = text.replace('иᴴ', '-ĩ')
    text = text.replace('и', '-i')
    
    text = text.replace('й', '-j')
    
    text = text.replace('кIкI', "-kː'")
    text = text.replace('кк', '-kː')
    text = text.replace('кI', "-k'")
    text = text.replace('къ', "-q͡χ'")
    text = text.replace('кь', "-t͡ɬ'")
    text = text.replace('к', '-k')
    
    text = text.replace('лълъ', '-ɬː')
    text = text.replace('лI', '-t͡ɬ')
    text = text.replace('лъ', '-ɬ')
    text = text.replace('л', '-l')
    
    text = text.replace('м', '-m')
    
    text = text.replace('нь', "-n'")
    text = text.replace('н', '-n')
    
    text = text.replace('оᴴ', '-õ')
    text = text.replace('о', '-o')
    
    text = text.replace('п', '-p')
    
    text = text.replace('р', '-r')
    
    text = text.replace('сс', '-sː')
    text = text.replace('с', '-s')
    
    text = text.replace('тI', "-t'")
    text = text.replace('т', '-t')
    
    text = text.replace('уᴴ', '-ũ')
    text = text.replace('у', '-u')
    
    text = text.replace('ф', '-f')
    
    text = text.replace('хх', '-χː')
    text = text.replace('хъ', '-q͡χ')
    text = text.replace('хь', '-x')
    text = text.replace('хI', "-χ'")
    text = text.replace('х', '-χ')
    
    text = text.replace('цIцI', "-t͡sː'")
    text = text.replace('цц', '-t͡sː')
    text = text.replace('цI', "-t͡s'")
    text = text.replace('ц', '-t͡s')
    
    text = text.replace('чIчI', "-t͡ʃː'")
    text = text.replace('чч', '-t͡ʃː')
    text = text.replace('чI', "-t͡ʃ'")
    text = text.replace('ч', '-t͡ʃ')
    
    text = text.replace('ш', '-ʃ')
    
    text = text.replace('щ', '-ʃː')
    
    text = text.replace('ъ', '-ʔ')
    
    text = text.replace('эᴴ', '-ẽ')
    text = text.replace('э', '-e')
    
    text = text.replace("-k-w", "-kʷ")
    text = text.replace("-k'-w", "-k'ʷ")
    text = text.replace("-ɡ-w", "-ɡʷ")
    text = text.replace("-h-w", "-hʷ")
    text = text.replace("-ʁ-w", "-ʁʷ")
    text = text.replace("-t͡ɬ-w", "-t͡ɬʷ")
    text = text.replace("-q͡χ-w", "-q͡χʷ")
    text = text.replace("-q͡χ'-w", "-q͡χ'ʷ")
    text = text.replace("-t͡ɬ'-w", "-t͡ɬ'ʷ")
    text = text.replace("-t͡ʃ'-w", "-t͡ʃ'ʷ")
    text = text.replace("-t'-w", "-t'ʷ")
    text = text.replace("-χː-w", "-χːʷ")
    text = text.replace("-t͡ʃ-w", "-t͡ʃʷ")
    text = text.replace("-ʃː-w", "-ʃːʷ")
    text = text.replace("-x-w", "-xʷ")
    text = text.replace("-ʃː'-w", "-ʃː'ʷ")
    text = text.replace("-d-w", "-dʷ")
    text = text.replace("-ʒ-w", "-ʒʷ")
    text = text.replace("-s-w", "-sʷ")
    text = text.replace("-sː-w", "-sːʷ")
    text = text.replace("-kː'-w", "-kː'ʷ")
    text = text.replace("-sː'-w", "-sː'ʷ")
    text = text.replace("-χ-w", "-χʷ")
    text = text.replace("-z-w", "-zʷ")
    text = text.replace("-r-w", "-rʷ")
    text = text.replace("-t-w", "-tʷ")
    text = text.replace("-l-w", "-lʷ")
    text = text.replace("-n-w", "-nʷ")
    text = text.replace("-t͡s'-w", "-t͡s'ʷ")

    text = text.replace('͡', '')

    if len(text) > 0 and text[0] == '-':
        text = text[1:]
    if len(text) > 0 and text[len(text)-1] == '-':
        text = text[:1]
    return text

# %%
ipa_list = []
for lemma in df['lemma']:
    ipa = ipaing(lemma)
    ipa_list.append(ipa)
    
df['ipa'] = ipa_list
# Out:
# <ipython-input-7-035d70c698bc>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ipa'] = ipa_list

# %%
sound_check = ['ю', 'ё', 'я', 'ь']
sound_borrowings = []
for i in df['ipa']:
    s_borr = 0
    for s in sound_check:
        if s in i:
            s_borr = 1
    sound_borrowings.append(s_borr)

df['sound_bor'] = sound_borrowings
# Out:
# <ipython-input-8-5b499af4f87f>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sound_bor'] = sound_borrowings

# %%
df['fin_bor'] = df[['bor','sound_bor']].sum(axis=1)
# Out:
# <ipython-input-9-9ac9ea9327bd>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['fin_bor'] = df[['bor','sound_bor']].sum(axis=1)

# %%
df = df.loc[(df['fin_bor'] < 1) & (df['id_meaning'] == 1)]

# %% [markdown]
# ## Подсчет type frequency

# %%
words = list(df['ipa'])

# %%
words
# Out:
# ['aː-χː',
#  'ã-h-a-j',
#  'ã-h-i',
#  'ã-h-a-j',
#  'ã-h-a-j-r',
#  'ã-h-a-r',
#  'ã-h-i',
#  'ã-h-i-b-a-ʁ-u',
#  'ã-h-i-r',
#  'ã-h-i-r',
#  'ã-h-i-r',
#  'ã-h-i-r',
#  'ã-h-i-χ-a-b',
#  'ã-h-i-χ-a-b-i-w',
#  'ã-h-i-χ-a-b-u',
#  "ã-h-i-χ-i-tʃ'-a-b",
#  "ã-h-i-χ-i-tʃ'-a-b-u",
#  "ã-h-i-tʃ'-a-b",
#  'ã-h-o',
#  'ã-h-o',
#  'a-b-a-b-a-j',
#  'a-b-a-b-e',
#  'a-b-a-d-a-d-i',
#  'a-b-a-d-a-d-i-l-a',
#  'a-b-a-d-a-l-i-l-l-a-h-i-l',
#  'a-b-a-d-i-j-a-b',
#  'a-b-a-d-u-l-a-b-a-d',
#  'a-b-a-j',
#  'a-b-d-i',
#  'a-b-i',
#  'a-b-i-r',
#  'a-b-i-r-χ-a',
#  'a-w-a-d-a-n-a-b',
#  'a-w-a-d-a-n-a-b',
#  'a-w-a-d-a-n-a-b-i-r',
#  'a-w-a-d-a-n-ɬ-i',
#  'a-w-a-d-a-n-ɬ-i',
#  'a-w-a-d-a-n-ɬ-i',
#  'a-w-a-d-a-n-ɬ-i',
#  'a-w-a-r-a',
#  'a-w-a-r-a',
#  'a-w-a-r-a',
#  'a-w-a-r-a',
#  'a-ɡ-i-b-a',
#  'a-d-a-b-ɬː-i',
#  'a-d-a-b-ɬː-i',
#  "a-d-i-n-m-tʃ'-u",
#  'a-z-a-l-i-j-a-b',
#  'a-z-b-a-r',
#  'a-z-b-a-r',
#  'a-z-b-a-r',
#  'a-z-b-a-r',
#  'a-j',
#  'a-j',
#  'a-j',
#  'a-j',
#  'a-j-ʁ-i-r',
#  'a-j-d-a-b -d-a-n-i -d-u-j',
#  'a-kʷ-a-r-a-ɬ-i',
#  'a-kʷ-a-r-a-s-a-r',
#  'a-kʷ-r-a-j-n-tʃ-a',
#  'a-k-u-j',
#  'a-k-u-r-a-n-tʃ-i',
#  "a-l-a-z-a-n-i-b -qχ'ʷ-a-t'-i",
#  'a-l-a-l-a-j',
#  'a-l-a-t',
#  'a-l-a-t',
#  'a-m-b-u-r',
#  'a-m-b-u-r',
#  'a-m-b-u-r',
#  'a-m-b-u-r',
#  'a-m-b-u-r-b-a-j',
#  'a-m-d-a-j',
#  'a-m-d-i',
#  'a-m-d-i-qχ-a-b',
#  'a-m-i',
#  "a-n-d-a-tʃ'-a-b",
#  'a-n-d-u',
#  'a-n-ʒ-i',
#  'a-n-ʒ-a',
#  'a-n-ʒ-a-qχ-a-n',
#  'a-n-ʒ-i',
#  'a-n-z-i',
#  'a-n-z-i',
#  'a-n-z-i',
#  'a-n-z-i',
#  'a-n-z-i-ʁ-u',
#  'a-n-i-ʃː',
#  'a-n-i-ʃː',
#  'a-n-i-ʃː-a-b',
#  'a-n-i-ʃː-tɬ-i',
#  'a-n-ɬː-a',
#  'a-n-ɬː-a',
#  'a-n-ɬː-a',
#  'a-n-ɬː-a',
#  'a-n-ɬː-a',
#  'a-n-ɬː-a-k-ũ-j',
#  'a-n-s-i',
#  'a-n-s-i',
#  'a-n-s-i',
#  'a-n-s-i',
#  'a-n-s-i-ɬ-i-r',
#  'a-n-s-i-r-ɬ-i',
#  'a-n-sː-a-j',
#  'a-n-sː-i',
#  'a-n-sː-a',
#  'a-n-sː-a',
#  'a-n-sː-a',
#  'a-n-sː-a',
#  'a-n-sː-a-j',
#  'a-n-sː-a-j-r',
#  'a-n-sː-a-j-χ-a-b',
#  'a-n-sː-a-r',
#  'a-n-sː-a-r',
#  'a-n-sː-a-r',
#  'a-n-sː-a-r',
#  'a-n-sː-i',
#  'a-n-sː-i',
#  'a-n-sː-i',
#  'a-n-sː-i-r',
#  'a-n-t-a',
#  'a-n-t-a-b',
#  'a-n-t-a-r',
#  'a-n-t-a-r',
#  'a-n-t-a-r',
#  'a-n-t-a-r',
#  'a-n-t-o',
#  'a-n-χʷ-a-j',
#  'a-n-χ-u-j',
#  'a-n-χʷ-a-ɬ-i',
#  'a-n-χʷ-a-b',
#  'a-n-χʷ-a-b',
#  'a-n-χʷ-a-b',
#  'a-n-χʷ-a-b',
#  'a-n-χʷ-a-b-a-h',
#  'a-n-χʷ-a-b-a-h-i-r',
#  'a-n-χʷ-a-b-n-aː',
#  'a-n-χʷ-a-j',
#  'a-n-χʷ-a-j-χ-a-b -n-a',
#  'a-n-χʷ-a-m-a-l-a-b',
#  'a-n-χʷ-a-r',
#  'a-n-χʷ-a-r',
#  'a-n-χʷ-a-r',
#  'a-n-χʷ-a-r',
#  'a-n-χʷ-a-χ-o-b',
#  'a-n-χʷ-a-χ-o-b',
#  'a-n-χʷ-a-χ-o-b',
#  'a-n-χʷ-a-χ-o-b',
#  'a-n-χ-u-j',
#  'a-n-tʃ-a',
#  'a-n-tʃ-a',
#  'a-n-tʃ-i-ɬ-i',
#  'a-n-tʃ-i-χ-e',
#  'a-n-tʃː-u',
#  'a-n-tʃː-u',
#  'a-n-ʃː-i',
#  'a-n-ʃː-i',
#  'a-n-ʃː-i',
#  'a-n-ʃː-i',
#  'a-n-ʃː-i',
#  'a-n-ʃː-i',
#  'a-n-ʃː-i',
#  'a-n-ʃː-i',
#  'a-n-ʃː-i-d-a',
#  'a-n-ʃː-i-d-a',
#  'a-n-ʃː-i-d-a',
#  'a-n-ʃː-i-d-a',
#  'a-n-ʃː-i-d-a-a-n-ʃː-i',
#  'a-n-ʃː-i-d-a-n-ʃː-i',
#  "a-n-ʃː-i-k'ʷ-a-l-a",
#  "a-n-ʃː-i-k'ʷ-a-l-a",
#  "a-n-ʃː-i-k'ʷ-a-l-a",
#  "a-n-ʃː-i-k'ʷ-a-l-a",
#  'a-n-ʃː-i-l-a',
#  'a-n-ʃː-i-χʷ-a-l-a',
#  'a-n-ʃː-i-χʷ-a-l-l-a',
#  'a-n-ʃː-i-tsː-u-b',
#  'a-r-a',
#  'a-r-a',
#  'a-r-a',
#  'a-r-a',
#  'a-r-a-d-a-j',
#  'a-r-a-d-i',
#  'a-r-ʁ-u-t',
#  'a-r-ʒ-a-j',
#  'a-r-ʒ-i',
#  'a-r-ʒ-a',
#  'a-r-ʒ-a',
#  'a-r-ʒ-a',
#  'a-r-ʒ-a',
#  'a-r-ʒ-a-b',
#  'a-r-ʒ-a-ʒ-a-j',
#  'a-r-ʒ-a-j',
#  'a-r-ʒ-a-r',
#  'a-r-ʒ-a-r',
#  'a-r-ʒ-i',
#  'a-r-ʒ-i-n -i-n-tʃ-u',
#  'a-r-ʒ-i-n-ʃː-ã-j',
#  'a-r-ʒ-i-r',
#  "a-r-qχ'ʷ-a",
#  "a-r-qχ'ʷ-a",
#  "a-r-qχ'ʷ-a-b",
#  "a-r-qχ'-u-j",
#  "a-r-qχ'-u-j-r",
#  "a-r-qχ'-u-j-χ-a-b -k-o-b-i",
#  "a-r-qχ'-u-j-tʃ'-a-b",
#  "a-r-qχ'-u-l",
#  "a-r-qχ'-u-l",
#  "a-r-qχ'-u-l",
#  "a-r-qχ'-u-l",
#  "a-r-qχ'-u-l-e",
#  'a-r-s-i',
#  'a-r-s-i',
#  'a-r-s-i-m-i-s-i-d-i',
#  'a-r-s-i-m-i-s-i-d-i',
#  'a-r-s-i-m-i-s-i-d-i',
#  'a-r-s-i-m-i-s-i-d-i',
#  'a-r-s-i-ɬ-i',
#  'a-r-s-i-χ-i-sː-u-b',
#  'a-r-t-a',
#  'a-r-u',
#  'a-r-u',
#  'a-r-u',
#  'a-r-u',
#  'a-r-u-k-u',
#  'a-r-u-k-u',
#  'a-r-u-k-u',
#  'a-r-u-k-u',
#  'a-r-u-sː-u-b',
#  'a-r-u-sː-u-b',
#  'a-r-χː-a-ʃː-a-b',
#  'a-r-χː-a-ʃː-i',
#  'a-r-χː-a-ʃː-i-r',
#  'a-r-χː-a-ʃː-i-χ-a-b',
#  'a-r-ʃː-a-j',
#  'a-r-ʃː-i',
#  'a-s-a',
#  'a-s-a',
#  'a-s-a',
#  'a-s-a',
#  'a-s-a-r',
#  'a-s-a-r',
#  'a-s-a-r',
#  'a-s-a-r',
#  'a-s-a-r',
#  'a-s-a-r',
#  'a-s-a-r',
#  'a-s-a-r',
#  'a-s-a-r',
#  'a-s-a-r',
#  'a-s-a-r',
#  'a-s-a-r',
#  'a-s-a-r',
#  'a-s-a-r',
#  'a-s-a-r',
#  'a-s-a-r-ʁ-a-b',
#  'a-s-a-r-l-a',
#  'a-s-a-r-χʷ-a-l-a',
#  'a-s-a-r-χʷ-a-l-a',
#  'a-s-a-s-a-r',
#  'a-s-a-s-a-r-b-i-kː-u',
#  'a-s-a-s-a-r-b-i-kː-u-χ-o-b',
#  'a-s-a-s-a-r-b-i-kː-u',
#  'a-s-i-kʷ-a-s-a-n-d-e',
#  "a-s-i-m-a-qχ'-a-b",
#  'a-sː-u-l-u',
#  'a-sː-u-l-u',
#  'a-sː-u-l-u-d-a-r-u',
#  'a-t-a-j',
#  'a-t-i',
#  'a-t-a-r',
#  'a-t-a-t-a-j',
#  'a-χ-i',
#  "a-χ'-m-a-j-qχ'ʷ-a-t'-i",
#  "a-χ-a-tɬ'-u-sː-u",
#  "a-χ-a-tɬ'-u-sː-u",
#  "a-χ-a-tɬ'-u-sː-u",
#  "a-χ-a-tɬ'-u-sː-u",
#  "a-χ-a-tɬ'-u-sː-u-j-d-e-r-a",
#  "a-χ-a-tɬ'-u-sː-u-j-d-e-r-a",
#  "a-χ-a-tɬ'-u-sː-u-sː-u-b",
#  "a-χ-a-tɬ'-u-sː-u-sː-u-b",
#  'a-χ-a-r-a',
#  'a-χ-a-r-a',
#  'a-χ-a-r-a-j-d-e-r-a',
#  'a-χ-a-r-a-sː-u-b',
#  'a-χ-a-r-a-sː-u-b',
#  'a-χ-a-r-a-sː-u-b',
#  'a-χ-a-r-a-sː-u-b',
#  "a-χ-a-r-a-χ-a-tɬ'-u-sː-u",
#  "a-χ-a-r-a-χ-a-tɬ'-u-sː-u-j-d-e-r-a",
#  'a-χ-a-r-e-r-u',
#  'a-χʷ-a',
#  'a-χʷ-a',
#  'a-χʷ-a',
#  'a-χʷ-a',
#  'a-χʷ-a',
#  'a-χʷ-a -i-h-i',
#  'a-χʷ-a-t-a-ɬ-i',
#  'a-χ-i',
#  'a-χ-i-χ-u-r-i',
#  'a-χ-i-m-u',
#  "a-χ-i-m-a-k'ʷ-a",
#  'a-χ-i-r-a-l-d-a',
#  'a-χ-i-r-l-a',
#  'a-χ-t-u',
#  'a-qχ-u',
#  'a-qχ-u',
#  "a-qχʷ-a-b-a-tɬ'-i",
#  'a-qχ-e-l-a-ɬ-i',
#  'a-qχ-i-l-a',
#  'a-qχ-i-l-d-a -w-a-h-i',
#  'a-qχ-i-l-d-a-ɬ-i',
#  'a-qχ-u-l',
#  'a-qχ-u-l',
#  'a-qχ-u-l',
#  'a-qχ-u-l',
#  'a-qχ-u-l-u',
#  'a-xʷ-a-ɬ-i',
#  'a-tsː-i',
#  'a-tʃ-a-j',
#  'a-tʃ-i',
#  'a-tʃ-u-j',
#  'a-tʃ-u-j',
#  'a-tʃ-a-j',
#  'a-tʃ-a-j-r',
#  'a-tʃ-a-tʃ-i',
#  'a-tʃʷ-a-j',
#  'a-tʃʷ-a-j-r',
#  'a-tʃʷ-a-j-χ-a-b',
#  'a-tʃ-i',
#  'a-tʃ-i',
#  'a-tʃ-i',
#  'a-tʃ-i',
#  'a-tʃ-i',
#  'a-tʃ-i-r',
#  'a-tʃ-i-χ-a-b',
#  'a-tʃ-k-i-b-a-ɬ-i',
#  'a-tʃ-u',
#  'a-tʃ-u',
#  'a-tʃ-u',
#  'a-tʃ-u',
#  'a-tʃ-u-h-a-l-i',
#  "a-tʃ-u-d-a -b-u-k'-i-χ-a-b",
#  'a-tʃ-u-r',
#  'a-tʃ-u-r-a',
#  'b-a-ʁ-a-r-ʁ-a-j',
#  'b-a-ʁ-a-r-ʁ-i',
#  'b-a-h-i',
#  "b-a-k'-a-r-a-j",
#  "b-a-k'-a-r-a-j",
#  "b-a-k'-a-r-a-j",
#  "b-a-k'-a-r-a-j",
#  "b-a-k'-a-r-a-j",
#  "b-a-k'-a-r-i",
#  "b-a-k'ʷ-a-ʃː-i",
#  "b-a-qχ'-a-j",
#  "b-a-qχ'-i",
#  "b-a-qχ'-a-b-a-qχ'-a-b",
#  "b-a-qχ'-a-b-a-qχ'-a-b",
#  "b-a-qχ'-a-b-a-qχ'-a-b",
#  "b-a-qχ'-a-b-a-qχ'-a-b",
#  "b-a-qχ'-a-b-a-χ-a-j",
#  "b-a-qχ'-a-b-a-χ-i",
#  "b-a-qχ'-a-ʃː-a-j",
#  "b-a-qχ'-a-ʃː-i",
#  "b-a-qχ'-a-ʃː-i-r",
#  "b-a-qχ'-u",
#  "b-a-tɬ'-a-b-u-tɬ-a-j",
#  "b-a-tɬ'-a-b-u-tɬ-i",
#  "b-a-tɬ'-i-ɬː-a",
#  "b-a-tɬ'-i-ɬː-a-k-u",
#  "b-a-tɬ'-i-ɬː-a-sː-u-b",
#  "b-a-tɬ'-u",
#  "b-a-tɬ'-u-b-a-tɬ'-u",
#  "b-a-tɬ'-u-sː-e-a",
#  "b-a-tɬ'-u-sː-e",
#  "b-a-tɬ'-u-sː-u-b",
#  'b-a-ɬ-a-r-ʁ-a-j',
#  'b-a-ɬː-i-n-i',
#  'b-a-ɬː-i-n-a',
#  'b-a-r-tɬ-i',
#  'b-a-r-tɬ-i',
#  'b-a-r-tɬ-i',
#  'b-a-r-tɬ-i',
#  "b-a-t'-a-ɬ-a-j",
#  "b-a-t'-a-ɬ-i",
#  'b-a-χ-i',
#  'b-a-χ-i',
#  'b-a-χ-i',
#  'b-a-χ-i',
#  'b-a-χ-i',
#  'b-a-χ-a-r-a-j',
#  'b-a-χ-a-r-i',
#  'b-a-χ-a-r-a',
#  'b-a-χ-a-r-i-r',
#  'b-a-χ-a-χ-i',
#  "b-a-ts'-a-j",
#  "b-a-ts'-a-j",
#  "b-a-ts'-a-j",
#  "b-a-ts'-a-j",
#  "b-a-ts'-i",
#  "b-a-ts'-i",
#  "b-a-ts'-i",
#  "b-a-ts'-i",
#  "b-a-ts'-i",
#  "b-a-ts'-i",
#  "b-a-ts'-i",
#  "b-a-ts'-i",
#  "b-a-ts'-i",
#  "b-a-ts'-j",
#  "b-a-tʃ'-a-j",
#  "b-a-tʃ'-a-j",
#  "b-a-tʃ'-a-m-a-l-a-b",
#  "b-a-tʃ'-a-m-a-l-a-b",
#  "b-a-tʃ'-a-m-a-l-a-b",
#  "b-a-tʃ'-a-m-a-l-a-b",
#  "b-a-tʃ'-i",
#  "b-a-tʃ'-i-r",
#  'b-a-tʃ-i',
#  'b-a-ʔ-a-b',
#  'b-e-ʁ-a-j',
#  'b-e-ʁ-i',
#  'b-e-ʁ-a-ʃ-a-j',
#  'b-e-ʁ-a-ʃ-i',
#  'b-e-ʁ-a-ʃ-u-t-a-ɬ-i',
#  'b-e-ʁʷ-a',
#  'b-e-ʁ-i-χ-a-b',
#  "b-e-ʁ-i-χ-i-tʃ'-a-b",
#  "b-e-kː'-a-ɬ-i",
#  "b-e-qχ'-u-j",
#  "b-e-qχ'ʷ-a-j",
#  "b-e-qχ'ʷ-a-b",
#  "b-e-qχ'ʷ-a-ɬ-i",
#  "b-e-qχ'ʷ-a-ɬ-i",
#  "b-e-qχ'ʷ-a-ɬ-i",
#  "b-e-qχ'ʷ-a-ɬ-i",
#  "b-e-qχ'-i-n",
#  "b-e-qχ'-i-n",
#  "b-e-qχ'-i-n",
#  "b-e-qχ'-i-n",
#  "b-e-qχ'-i-n-a-j",
#  "b-e-qχ'-i-n-i",
#  "b-e-tɬ'-a-r-a-ʁʷ-i",
#  "b-e-tɬ'-a-r-a-d-u",
#  "b-e-tɬ'-a-r-a-χ-i",
#  "b-e-tɬ'-a-r-u",
#  'b-e-tɬ-i',
#  'b-e-tɬ-a-χʷ-a-ɬ-i',
#  'b-e-tɬ-a-χʷ-a-ɬ-i',
#  'b-e-tɬ-a-χʷ-a-ɬ-i',
#  'b-e-tɬ-a-χʷ-a-ɬ-i',
#  'b-e-tɬ-a-χʷ-a-r',
#  'b-e-tɬ-i-b-u-tɬ-i',
#  'b-e-tɬ-i-r',
#  'b-e-tɬ-u',
#  'b-e-r-a-χː-a-j',
#  'b-e-r-a-χː-a-j',
#  'b-e-r-a-χː-a-j',
#  'b-e-r-a-χː-a-j',
#  'b-e-r-a-χː-i',
#  'b-e-r-a-χː-i',
#  'b-e-r-a-χː-i',
#  'b-e-r-a-χː-i',
#  'b-e-r-a-ʃː-a-j',
#  'b-e-r-a-ʃː-i',
#  'b-e-r-a-ʃː-i-χ-a-b',
#  'b-e-r-ʃ-a',
#  'b-e-r-ʃ-a-j',
#  'b-e-sː-u-χ-a',
#  'b-e-s-qχ-e',
#  'b-e-t-a-j',
#  'b-e-t-i',
#  "b-e-χ-u-t'-u",
#  "b-e-χ-u-t'-u-ʁʷ-a-n-d-a-b",
#  "b-e-χ-u-t'-u-sː-e-a-sː-e",
#  "b-e-χ-u-t'-u-sː-u-b",
#  'b-e-χː-u-j',
#  'b-e-χːʷ-a-j',
#  'b-e-χːʷ-a-b',
#  'b-e-χː-i-l-a-j',
#  'b-e-χː-i-l-i',
#  'b-e-χː-i-l-a',
#  'b-e-χː-i-l-a-r',
#  'b-e-χː-u-j-d-e-r-a',
#  'b-e-qχ-u-j',
#  'b-e-qχ-u-j',
#  'b-e-qχʷ-a-j',
#  "b-e-qχ-u-t'-u",
#  "b-e-qχ-u-t'-u-b-i-kː-i",
#  "b-e-qχ-u-t'-u-sː-u-b",
#  'b-e-tsː-a-t-a-b',
#  'b-e-tsː-a-t-i-r',
#  'b-e-tsː-i-χː-a-j',
#  'b-e-tsː-t-a-j',
#  "b-e-tʃ'-e-r",
#  "b-e-tʃ'-u-j",
#  "b-e-tʃ'-e-r-a-j",
#  "b-e-tʃ'-e-r-i",
#  "b-e-tʃ'-u-d-a",
#  "b-e-tʃ'-u-d-i",
#  "b-e-tʃ'-u-χ-a-j",
#  "b-e-tʃ'-u-χ-i",
#  "b-e-tʃ'-u-χ-a",
#  "b-e-tʃ'-u-χ-a",
#  "b-e-tʃ'-u-χ-a",
#  "b-e-tʃ'-u-χ-a",
#  "b-e-tʃ-e-k'-i",
#  "b-e-tʃ-e-k'-i-r",
#  'b-e-tʃ-i-b-e-χːʷ-a-j',
#  'b-e-tʃ-i-b-e-χː-u-j',
#  'b-e-tʃ-i-b-e-χːʷ-i-r',
#  'b-e-ʃ-t-a-j',
#  'b-e-ʃ-t-i',
#  'b-e-ʃ-t-i',
#  'b-e-ʃ-t-i',
#  'b-e-ʃ-t-i',
#  'b-e-ʃ-t-a-b-e-t-i',
#  'b-e-e-r-i',
#  'b-e-e-r-a',
#  'b-i-a-j',
#  'b-i-ʒ-i',
#  'b-i-ʒ-a-b',
#  'b-i-ʒ-i-χ-a-b',
#  'b-i-kː-a-j',
#  'b-i-kː-i',
#  'b-i-kː-a-kː-a-j',
#  'b-i-l-a-j',
#  'b-i-s-i',
#  'b-i-t-i',
#  "b-i-t'-i",
#  'b-i-χː-a-j',
#  'b-i-χː-i',
#  "b-i-χː-u-j-tʃ'-a-d-a",
#  'b-i-tʃ-i',
#  "b-i-tʃ'-a-j",
#  "b-i-tʃ'-a-j",
#  "b-i-tʃ'-a-j",
#  "b-i-tʃ'-a-j",
#  "b-i-tʃ'-a-b",
#  "b-i-tʃ'-a-b",
#  "b-i-tʃ'-a-b",
#  "b-i-tʃ'-a-b",
#  "b-i-tʃː'-i",
#  "b-i-tʃː'-i",
#  "b-i-tʃː'-i",
#  "b-i-tʃː'-i",
#  'b-i-tʃː-u-k-u-j',
#  'b-i-ʃ-a-j',
#  'b-i-ʃ-a-j',
#  'b-i-ʃ-a-j',
#  'b-i-ʃ-a-j',
#  'b-i-ʃ-a-j',
#  'b-i-ʃ-a-j',
#  'b-i-ʃ-a-j',
#  'b-i-ʃ-a-j',
#  'b-i-ʃ-a-j',
#  'b-i-ʃ-i',
#  'b-i-ʃ-i',
#  'b-i-ʃ-i',
#  'b-i-ʃ-i',
#  'b-i-ʃ-i',
#  'b-i-ʃ-i-r',
#  'b-i-ʃ-i-r',
#  'b-i-ʔ-i',
#  'b-i-ʔ-i-r',
#  "b-i-ʔ-i-tʃ'-a-b",
#  'b-o',
#  "b-o-r-tʃ'-a-j",
#  "b-o-r-tʃ'-i",
#  'b-u-aː-t-a-ɬ-i',
#  'b-u-ʁ-i',
#  "b-u-k'-a-j",
#  "b-u-k'-a-b-u-k'-a-b-u-ɬː-u",
#  "b-u-k'-a-b-u-k'-i-tʃ'-a-b",
#  "b-u-k'-a-b",
#  "b-u-k'-a-b",
#  "b-u-k'-a-b",
#  "b-u-k'-a-b",
#  "b-u-k'-a-b-u-ɬː-u",
#  "b-u-k'-a-b-χ'-a-l-e",
#  "b-u-k'-a-t-a-ɬ-i",
#  "b-u-k'-i",
#  "b-u-k'-i-χ-o-b",
#  'b-u-kː-a-j',
#  'b-u-kː-i',
#  'b-u-kː-i',
#  "b-u-qχ'-i",
#  "b-u-qχ'-a-qχ'-i",
#  'b-u-tɬ-a-j',
#  'b-u-r-d-a-j',
#  'b-u-t-a-j',
#  'b-u-χː-a-j',
#  'b-u-χː-a-j',
#  'b-u-χː-a-j',
#  'b-u-χː-a-j',
#  'b-u-χː-a-j',
#  'b-u-χː-a-j',
#  'b-u-χː-a-j',
#  'b-u-χː-a-j',
#  'b-u-χː-a-j',
#  'b-u-χː-a-j',
#  'b-u-χː-a-j',
#  'b-u-χː-a-j',
#  'b-u-χː-i',
#  'b-u-ʃː-a-ʃː-i',
#  'b-a-ʁ-a-r-ʁ-a-b',
#  'b-a-ʁ-a-r-ʁ-a-j',
#  'b-a-ʁ-a-r-ʁ-a-j',
#  'b-a-ʁ-a-r-ʁ-a-j',
#  'b-a-ʁ-a-r-ʁ-a-j',
#  'b-a-ʁ-a-r-ʁ-a-j-r',
#  'b-a-ʁ-a-r-ʁ-a-j-χ-a-b',
#  'b-a-ʁ-a-r-ʁ-i',
#  'b-a-ʁ-a-r-ʁ-i-r',
#  'b-a-ʁ-a-r-ʁ-i-χ-a-b',
#  'b-a-ʁ-u-ʃ-a-j',
#  'b-a-ʁ-u-ʃ-i',
#  'b-a-ʁ-u-ʃ-u-t-a-ɬ-i',
#  'b-a-h-a-t-a-ɬ-i',
#  'b-a-h-i',
#  'b-a-h-i',
#  'b-a-h-i',
#  'b-a-h-i',
#  'b-a-h-i-χ-a-b',
#  "b-a-qχ'-a-b",
#  "b-a-qχ'-a-j",
#  "b-a-qχ'-a-j-m-a-l-a-b",
#  "b-a-qχ'-a-j-r",
#  "b-a-qχ'-i",
#  "b-a-qχ'-i-r",
#  "b-a-qχ'-i-χ-a-b",
#  "b-a-tɬ'-a-d-a-χ-i-sː-u-b",
#  'b-a-ɬː-i-n-a',
#  'b-a-ɬː-i-n-a-b-i-r',
#  'b-a-ɬː-i-n-a-j',
#  'b-a-ɬː-i-n-a-j-r',
#  'b-a-ɬː-i-n-a-j-χ-o-b',
#  'b-a-ɬː-i-n-a-t-a-χ-o-b',
#  'b-a-ɬː-i-n-a-tsː-u-b',
#  'b-a-ɬː-i-n-i',
#  'b-a-ɬː-i-n-i-r',
#  "b-a-ɬː-i-n-i-χ-i-tʃ'-a-b",
#  "b-a-ɬː-i-n-i-tʃ'-a-b",
#  'b-a-r-a-χː-a-j',
#  'b-a-r-a-χː-i',
#  'b-a-r-a-ʃː-a-b',
#  'b-a-r-a-ʃː-a-j',
#  'b-a-r-a-ʃː-i',
#  'b-a-r-a-ʃː-i-r',
#  'b-a-r-a-ʃː-i-χ-a-b',
#  "b-a-tʃ'-a-b",
#  "b-a-tʃ'-a-j",
#  "b-a-tʃ'-i",
#  'b-e-ʁ-i',
#  'b-e-ʁ-i-r',
#  'b-e-ʁ-i-χ-a-b',
#  "b-e-ʁ-i-tʃ'-a",
#  "b-e-ʁ-i-tʃ'-a-b",
#  "b-e-ʁ-i-tʃ'-a-b-i-r",
#  "b-e-ʁ-i-tʃ'-a-d-a",
#  "b-e-ʁ-i-tʃ'-i-r",
#  "b-e-tɬ'-a-r-a-d-u",
#  "b-e-tɬ'-a-r-a-d-u-k-u",
#  "b-e-tɬ'-a-r-a-d-u-sː-u-b",
#  "b-e-tɬ'-a-r-u-sː-u-b",
#  'b-e-tɬ-a-χʷ-a-ɬ-i',
#  'b-e-tɬ-i',
#  'b-e-r-ʃ-a-j',
#  'b-e-s-qχ-a',
#  'b-e-s-qχ-a-d-i',
#  'b-e-s-qχ-e-sː-u-b',
#  'b-e-t-a-j',
#  'b-e-t-i',
#  "b-e-χ-u-t'-u",
#  "b-e-χ-u-t'-u-sː-e",
#  "b-e-χ-u-t'-u-sː-e-sː-u-b",
#  "b-e-χ-u-t'-u-sː-u-b",
#  'b-e-χː-i-l-a',
#  'b-e-χː-i-l-a-j',
#  'b-e-χː-i-l-a-r',
#  'b-e-χː-i-l-a-r-χ-a',
#  'b-e-χː-i-l-a-r-χ-a-sː-u-b',
#  'b-e-χː-i-l-a-tsː-u-b',
#  'b-e-χː-i-l-i',
#  'b-e-χː-i-l-i-χ-a-b',
#  'b-e-χː-i-l-o',
#  'b-e-χː-i-ɬː-a-sː-u-b',
#  'b-e-χː-u-j',
#  'b-e-χː-u-j-d-e-r-a',
#  'b-e-qχ-u-j-ɬ-a-b',
#  "b-e-qχ-u-t'-u",
#  "b-e-qχ-u-t'-u-k-u",
#  "b-e-qχ-u-t'-u-r-u-b-e-qχ-u-t-u",
#  "b-e-qχ-u-t'-u-sː-u-b",
#  "b-e-tʃ'-e-r",
#  "b-e-tʃ'-e-r-a-b",
#  "b-e-tʃ'-e-r-a-j",
#  "b-e-tʃ'-e-r-a-j-m-a-l-a-b",
#  "b-e-tʃ'-e-r-i",
#  "b-e-tʃ'-e-r-i-d-e-r-a",
#  "b-e-tʃ'-u-d-a",
#  "b-e-tʃ'-u-d-i",
#  "b-e-tʃ'-u-d-i-r",
#  "b-e-tʃ-e-k'-a-j",
#  "b-e-tʃ-e-k'-i",
#  "b-e-tʃ-e-k'-i",
#  "b-e-tʃ-e-k'-o",
#  'b-e-tʃ-i',
#  'b-e-tʃː-i-kʷ-a-b',
#  'b-e-tʃː-i-kʷ-a-j',
#  'b-e-tʃː-i-k-u-j',
#  'b-e-ʃ-t-a',
#  'b-e-ʃ-t-i',
#  'b-e-ʔ-e-r-a',
#  'b-e-ʔ-e-r-a-j',
#  'b-e-ʔ-e-r-i',
#  'b-i-ʁ-a-b',
#  'b-i-ʁ-a-j',
#  'b-i-ʁ-a-j-m-a-l-a-b',
#  'b-i-ʁ-a-j-χ-a-b',
#  'b-i-ʁʷ-a-b',
#  'b-i-ʁʷ-a-j',
#  'b-i-ʁ-i',
#  'b-i-ʁ-i-d-e-r-a',
#  'b-i-ʁ-i-χ-a-b',
#  "b-i-ʁ-i-χ-i-tʃ'-a-b",
#  "b-i-ʁ-i-tʃ'-a-b",
#  'b-i-ʁ-u-ɬ-a-b',
#  'b-i-h-a-j-r',
#  'b-i-h-i',
#  'b-i-ʒ-a-b',
#  'b-i-ʒ-a-j',
#  'b-i-ʒ-i',
#  'b-i-ʒ-i-r',
#  'b-i-ʒ-i-χ-a-b',
#  'b-i-kː-a-b',
#  'b-i-kː-a-j',
#  'b-i-kː-i',
#  'b-i-kː-i-r',
#  'b-i-kː-i-χ-a-b',
#  "b-i-qχ'-a-j",
#  'b-i-l-a-b',
#  'b-i-l-a-j',
#  'b-i-l-a-j-r',
#  'b-i-l-a-j-χ-a-b',
#  'b-i-l-a-l-a-j',
#  'b-i-ɬː-i',
#  'b-i-ɬː-i',
#  'b-i-ɬː-i',
#  'b-i-ɬː-i',
#  'b-i-ɬː-i-χ-a-b',
#  'b-i-s-a-b',
#  'b-i-s-a-j',
#  'b-i-s-i',
#  'b-i-s-i-r',
#  "b-i-t'-a-b",
#  "b-i-t'-a-j",
#  "b-i-t'-a-j",
#  "b-i-t'-a-j",
#  "b-i-t'-i",
#  "b-i-t'-i",
#  'b-i-t-a-b',
#  'b-i-t-a-j',
#  'b-i-t-a-t-a-j',
#  'b-i-t-a-t-i',
#  'b-i-t-i',
#  'b-i-t-i-r',
#  "b-i-tʃ'-a-b",
#  "b-i-tʃ'-a-j",
#  "b-i-tʃ'-tʃ-a-b",
#  'b-i-tʃ-i',
#  'b-i-ʃ-a-b',
#  'b-i-ʃ-a-j',
#  'b-i-ʃ-i',
#  'b-i-ʔ-a-b',
#  'b-i-ʔ-a-b-tsː-u-b',
#  'b-i-ʔ-i',
#  "b-k'-a-χʷ-a-l-a",
#  "b-o-r-tʃ'-a-j",
#  "b-o-r-tʃ'-a-j-r",
#  "b-o-r-tʃ'-i",
#  "b-o-r-tʃ'-i-r",
#  "b-o-tʃ'-u-χ-a",
#  "b-o-tʃ'-u-χ-a-j",
#  "b-o-tʃ'-u-χ-a-j-χ-a-b",
#  "b-o-tʃ'-u-χ-a-r",
#  "b-o-tʃ'-u-χ-i",
#  "b-o-tʃ'-u-χ-o",
#  "b-u-k'-a-b",
#  "b-u-k'-a-j",
#  "b-u-k'-a-j-m-a-l-a-b",
#  "b-u-k'-a-j-m-a-l-a-b",
#  "b-u-k'-a-j-r",
#  "b-u-k'-a-j-χ-a-b",
#  "b-u-k'-a-l-l-a",
#  "b-u-k'-i",
#  "b-u-k'-i-k-a-b-t-a-l-u",
#  "b-u-k'-i-r",
#  "b-u-k'-i-r-h-i-r-tʃː-i-r",
#  "b-u-k'-i-χ-a-b",
#  'b-u-kː-a-j',
#  'b-u-kː-a-j',
#  'b-u-kː-i-d-e-r-a',
#  'b-u-kː-i-r',
#  'b-u-t-a-j',
#  'b-u-χː-a-b',
#  'b-u-ʔ-a-j',
#  'b-u-ʔ-a-t-a-χ-o-b',
#  'b-aː-b-u',
#  'b-a-i',
#  'b-a-i',
#  'b-a-b-a-d-i-l-a -r-a-h-i',
#  'b-a-b-a-d-i-l-a-ɬ-i',
#  'b-a-b-a-d-i-l-a-r',
#  'b-a-b-u',
#  'b-a-ʕ-a-d-i',
#  'b-a-ʕ-a-d-a-ɬ-i',
#  'b-a-ʕ-a-d-i',
#  'b-a-ʕ-a-d-i-r',
#  'b-a-ʕ-a-j',
#  'b-a-ɡ-a-n',
#  'b-a-ɡ-a-m-a-ɬ-i-ɬː-i',
#  'b-a-ɡ-a-n',
#  'b-a-ɡ-a-n-ɬː-i',
#  'b-a-ɡʷ-a-n-ɬ-i',
#  'b-a-ʁ-a-b-a-tʃ-a-r-a-j',
#  'b-a-ʁ-a-b-a-tʃ-a-r-i',
#  'b-a-ʁ-a-r-ʁ-a-j',
#  'b-a-ʁ-a-r-ʁ-i-r',
#  'b-a-ʁ-u-ʃ-i-r',
#  'b-a-h-a',
#  'b-a-h-a-j',
#  'b-a-h-a-j',
#  'b-a-h-a-j',
#  'b-a-h-a-j',
#  'b-a-h-i',
#  'b-a-h-i',
#  'b-a-h-i',
#  'b-a-h-i',
#  'b-a-h-i',
#  'b-a-h-i',
#  'b-a-h-i',
#  'b-a-h-i',
#  'b-a-h-i',
#  'b-a-h-a',
#  'b-a-h-a-b',
#  'b-a-h-a-h-i',
#  'b-a-h-a-d-u-r',
#  'b-a-h-a-d-u-r',
#  'b-a-h-a-d-u-r',
#  'b-a-h-a-d-u-r',
#  'b-a-h-a-d-u-r',
#  'b-a-h-a-d-u-r',
#  'b-a-h-a-d-u-r',
#  'b-a-h-a-d-u-r',
#  'b-a-h-a-d-u-r',
#  'b-a-h-a-d-u-r-ɬ-i',
#  'b-a-h-a-d-u-r-ɬ-i',
#  'b-a-h-a-d-u-r-ɬ-i',
#  'b-a-h-a-d-u-r-ɬ-i',
#  'b-a-h-a-j',
#  'b-a-h-a-j',
#  'b-a-h-a-j',
#  'b-a-h-a-j',
#  'b-a-h-a-j-m-a-l-a-b',
#  'b-a-h-a-j-m-a-l-a-b',
#  'b-a-h-a-j-m-a-l-a-b',
#  'b-a-h-a-j-m-a-l-a-b',
#  'b-a-h-a-j-χ-a-b',
#  'b-a-h-a-ɬː-i',
#  'b-a-h-a-n-a',
#  'b-a-h-a-n-a',
#  'b-a-h-a-n-a',
#  'b-a-h-a-n-a',
#  'b-a-h-a-n-a-j',
#  'b-a-h-a-t-a-ɬ-i',
#  'b-a-h-a-t-a-χ-o-b',
#  'b-a-h-a-ts-a',
#  'b-a-h-a-ts-a',
#  'b-a-h-a-ts-a',
#  'b-a-h-a-ts-a',
#  "b-a-h-a-tʃ'-a-b",
#  'b-a-h-i-r',
#  'b-a-h-i-χ-a-b-i-r',
#  "b-a-h-i-χ-i-tʃ'-a-b",
#  "b-a-h-i-χ-i-tʃ'-a-b",
#  'b-a-d-a-ʁ-u-d-u-r',
#  'b-a-ʒ-a-r-a-j',
#  'b-a-ʒ-a-r-i',
#  'b-a-ʒ-a-r-a-b',
#  'b-a-ʒ-a-r-a-b',
#  'b-a-ʒ-a-r-a-b',
#  'b-a-ʒ-a-r-a-b',
#  'b-a-ʒ-a-r-e-r-χ-i',
#  'b-a-ʒ-a-r-i',
#  'b-a-ʒ-a-r-i-r',
#  'b-a-ʒ-a-r-i-r',
#  'b-a-ʒ-a-r-i-r',
#  'b-a-ʒ-a-r-i-r',
#  'b-a-ʒ-a-r-i-r-ɬː-i',
#  'b-a-ʒ-a-r-i-r-ɬː-i',
#  'b-a-ʒ-a-r-i-r-ɬː-i',
#  'b-a-ʒ-a-r-i-r-ɬː-i',
#  'b-a-ʒ-a-r-i-χ-a-b',
#  'b-a-ʒ-a-r-i-χ-a-b',
#  'b-a-z-a-r-z-i-w',
#  "b-a-z-a-r-χ'-a-r-qχ'",
#  'b-a-i-r',
#  'b-a-j',
#  'b-a-j',
#  'b-a-j',
#  'b-a-j',
#  'b-a-j-a-n',
#  'b-a-j-a-n',
#  'b-a-j-a-n',
#  'b-a-j-a-n',
#  'b-a-j-a-n-a-j',
#  'b-a-j-a-n-i',
#  'b-a-j-a-n-a-b',
#  'b-a-j-a-n-a-b',
#  'b-a-j-a-n-i-r',
#  'b-a-j-a-n-ɬ-i',
#  'b-a-j-a-n-ɬ-i',
#  'b-a-j-a-n-ɬ-i',
#  'b-a-j-a-n-ɬ-i',
#  'b-a-j-b-a-χ-i',
#  'b-a-j-b-i-x-i',
#  'b-a-j-b-i-x-i',
#  'b-a-j-b-i-x-i',
#  'b-a-j-b-i-x-i',
#  'b-a-j-b-i-x-i-r',
#  'b-a-j-d-a-n',
#  'b-a-j-d-a-n',
#  'b-a-j-ɬ-i',
#  'b-a-j-ɬ-i-k-u',
#  'b-a-j-ɬ-i-sː-u-b',
#  "b-a-k'-a-r-i",
#  "b-a-k'-a-r-i",
#  "b-a-k'-a-r-i-r",
#  "b-a-k'ʷ-a-b",
#  "b-a-k'ʷ-a-l",
#  "b-a-k'ʷ-a-l",
#  "b-a-k'ʷ-a-l",
#  "b-a-k'ʷ-a-l",
#  "b-a-k'ʷ-a-l-k'-a-n-tʃ'-u",
#  "b-a-k'ʷ-a-l-k'-a-n-tʃ'-u",
#  "b-a-k'ʷ-a-ʃː-a-j",
#  "b-a-k'ʷ-a-ʃː-i",
#  "b-a-k'ʷ-a-ʃː-i-r",
#  "b-a-k'-u-j",
#  "b-a-k'-u-j-r",
#  "b-a-k'-u-j-χ-a-b",
#  'b-a-k-a-l',
#  "b-a-qχ'-a-b",
#  "b-a-qχ'-a-b",
#  "b-a-qχ'-a-b",
#  "b-a-qχ'-a-b",
#  "b-a-qχ'-a-b-u-ɬː-a",
#  "b-a-qχ'-a-b-u-ɬː-u-k-u",
#  "b-a-qχ'-a-ʃː-i",
#  "b-a-qχ'-a-ʃː-a-b",
#  "b-a-qχ'-a-ʃː-a-j",
#  "b-a-qχ'-a-ʃː-a-j-r",
#  "b-a-qχ'-a-ʃː-i",
#  "b-a-qχ'-a-ʃː-i-r",
#  "b-a-qχ'-e-r-χ-i",
#  "b-a-qχ'-e-r-χ-i",
#  "b-a-qχ'-e-r-χ-i",
#  "b-a-qχ'-e-r-χ-i",
#  "b-a-qχ'-e-r-qχ-i-sː-u-b",
#  "b-a-qχ'-i-r",
#  "b-a-qχ'-i-χ-a-b",
#  "b-a-qχ'-i-χ-i-tʃ'-a-b",
#  "b-a-qχ'-i-χ-i-tʃ'-a-b",
#  "b-a-qχ'-i-χ-i-tʃ'-a-b",
#  "b-a-qχ'-i-χ-i-tʃ'-a-b",
#  "b-a-qχ'-o",
#  "b-a-qχ'-u",
#  "b-a-tɬ'-i",
#  "b-a-tɬ'-i",
#  "b-a-tɬ'-i",
#  "b-a-tɬ'-i",
#  "b-a-tɬ'-a-d-a-χ-i",
#  "b-a-tɬ'-a-r",
#  "b-a-tɬ'-a-χː-u-r",
#  "b-a-tɬ'-i",
#  "b-a-tɬ'-i",
#  "b-a-tɬ'-i",
#  "b-a-tɬ'-i",
#  "b-a-tɬ'-i",
#  "b-a-tɬ'-i",
#  "b-a-tɬ'-i",
#  "b-a-tɬ'-i",
#  "b-a-tɬ'-i-ɬː-a",
#  "b-a-tɬ'-u",
#  "b-a-tɬ'-u-sː-e-k-u",
#  "b-a-tɬ'-u-sː-e-sː-u-b",
#  "b-a-tɬ'-u-ɬ-i-r",
#  "b-a-tɬ'-u-r",
#  ...]

# %%
type_freq = {}
stop = ['', '\n']
for word in words:
    frags = word.split('-')
    for f in frags:
        if f not in stop:
            if f in type_freq.keys():
                type_freq[f] += 1
            else:
                type_freq[f] = 1

# %%
type_f = []
type_sum = sum(type_freq.values())
for i in type_freq.values():
    type_f.append(i/type_sum)

# %%
import pandas as pd
df_type = pd.DataFrame()
df_type['segment'] = type_freq.keys()
df_type['dict_value'] = type_freq.values()
df_type['dict_frequency'] = type_f

# %%
df_type.head()
# Out:
#     segment  dict_value  dict_frequency
# 0        aː          30        0.000267
# 1        χː         783        0.006964
# 2        ã          96        0.000854
# 3         h        2088        0.018569
# 4         a       21243        0.188922
# ..      ...         ...             ...
# 128     a             1        0.000009
# 129      uI           1        0.000009
# 130    tsːI           1        0.000009
# 131     ʃːʷ           2        0.000018
# 132      ẽ          14        0.000125
#
# [133 rows x 3 columns]

# %%
df_type.to_csv('botl_dict_res.csv')
