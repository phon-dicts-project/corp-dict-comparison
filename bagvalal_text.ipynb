# %%
my_file = 'data/bagv_data.txt'

data = open(my_file, 'r', encoding = 'utf-8').read()

# %%
data = data.replace('\n\n', '\t\t')
data = data.replace('\n', ' ')
data = data.replace('\t', '\n')
data = data.replace('  ', ' ')
data = data.replace('-', '')
data = data.replace('=', '')
data = data.replace('.', '')
data = data.replace(',', '')
data = data.replace('?', '')
data = data.replace('!', '')
data = data.replace('“', '')
data = data.replace('—', '')
data = data.replace(':', '')
data = data.replace('”', '')
data = data.replace(';', '')
data = data.replace('(', '')
data = data.replace(')', '')
data = data.replace('’', "'")

# %%
print(data)
# Out:
# k@anY istorija hac'aralayob hac'albíralayob wekYir buk'abo ek@a bíra han ebeb han ebeb tuXumyaS Xindi sanilibo buk'abo ek@a la['i buk'ur barDanadi pAj buk'ur Xorabi hAra]i buk'ur ata[abi c'abaL'oli buk'ur manuq'abi ebeb tuXumYiY wuk'a hin['aw o}ur <adlu Dórùb buk'a haniY haniY tuXumYiY Xalq' o}Wa mut'i<aba buk'ur ebeb tuXumYiY hin['aw wi}irùw wuk'a q'ar hômo <adlu hômo baZari hômo tuXumabayi baL'i DaHda buk'abo ek@a ce}ub ce}ur dan kWaXXir buk'abo  ek@a an]is hara]iSalur la['iSalub musa kWaXXibo ek@a buq'ubo bihamo oblóna hin['ab hins'ayi buhuro ekunôX buk'uro ek@a c'abalahandayila bóro la['iSalur bajbihi Dó L@ahróra hara]iSa hin['ab hins'ayi gorla Dóro ekunôX buk'uro ek@a la['iSalur L@ahrùb tup bahabo ek@a gor baL'ani <oloqabi a}ir ['ihi hec'ôyiX hara]iSaluw hin['aw}ur heL'i cewdala hek@a hurhirabiSe la['iSaluba iyib ari tupiY q'at'al bac'irùb bijarô iyi betôyoba we['e orur iyi hurhiri['irô oruba c@anôyob ek@a ari q'at'al bac'irôX we['edi q'at'al bac'irôX we['edila heL'ibo la['iSa b
# ...

# %%
stop = ["'", ' ', '’', '@', 'W']

for l in data:
    if l not in stop:
        data = data.replace(l, '-'+l)
        stop.append(l)
        
data = data.replace('@', "'-w")

#data = data.replace('Y', 'ɫ̄')
data = data.replace('Y', 'ɬː')

#data = data.replace('y', 'ɫ')
data = data.replace('y', 'ɬ')

data = data.replace('L', 'tɬ')
data = data.replace('R', 'ʁ')

#data = data.replace('í', 'ū')
data = data.replace('í', 'uː')

#data = data.replace('S', 's̄')
data = data.replace('S', 'sː')

#data = data.replace('D', 'ǯ')
data = data.replace('D', 'd͡ʒ')

data = data.replace('A', 'ã')

#data = data.replace(']', 'š')
data = data.replace(']', 'ʃ')

#data = data.replace('[', 'č')
data = data.replace('[', 't͡ʃ')

#data = data.replace('}', 's̄̌')
data = data.replace('}', 'ʃː')

data = data.replace('<', 'ʕ')

#data = data.replace('ó', 'ē')
data = data.replace('ó', 'eː')

#data = data.replace('ù', 'ō')
data = data.replace('ù', 'oː')

data = data.replace('W', '-w')

#data = data.replace('ô', 'ā')
data = data.replace('ô', 'aː')

#data = data.replace('Z', 'ž')
data = data.replace('Z', 'ʒ')

#data = data.replace('ø', 'ī')
data = data.replace('ø', 'iː')

data = data.replace('U', 'ũ')
data = data.replace('‘', "'")
data = data.replace('>', 'ʔ')

#data = data.replace('Ô', 'ā̃')
data = data.replace('Ô', 'ãː')

#data = data.replace('щ', 'ō')
data = data.replace('щ', 'oː')

#data = data.replace('ф', 'ā')
data = data.replace('ф', 'aː')

#data = data.replace('ш', 'ī')
data = data.replace('ш', 'iː')

#data = data.replace('Ù', 'ō̃')
data = data.replace('Ù', 'õː')

#data = data.replace('Í', 'ū̃')
data = data.replace('Í', 'ũː')

#data = data.replace('V', 'X̄')
data = data.replace('V', 'χː')

data = data.replace('X', 'χ')

#data = data.replace('У', 'ē̃')
data = data.replace('У', 'ẽː')

#data = data.replace('у', 'ē')
data = data.replace('у', 'eː')

data = data.replace('C', 'tsː') #???

#data = data.replace('Ó', 'ē̃')
data = data.replace('Ó', 'ẽː')

#data = data.replace('Ø', 'ī̃')
data = data.replace('Ø', 'ĩː')

data = data.replace('H', 'ħ')

data = data.replace('I', 'ĩ')
data = data.replace("i'", "i")

# %%
data = data.replace("-k-w", "-kʷ")
data = data.replace("-k'-w", "-k'ʷ")
data = data.replace("-ɡ-w", "-ɡʷ")
data = data.replace("-h-w", "-hʷ")
data = data.replace("-ʁ-w", "-ʁʷ")
data = data.replace("-t͡ɬ-w", "-t͡ɬʷ")
data = data.replace("-q͡χ-w", "-q͡χʷ")
data = data.replace("-q͡χ'-w", "-q͡χ'ʷ")
data = data.replace("-t͡ɬ'-w", "-t͡ɬ'ʷ")
data = data.replace("-t͡ʃ'-w", "-t͡ʃ'ʷ")
data = data.replace("-t'-w", "-t'ʷ")
data = data.replace("-χː-w", "-χːʷ")
data = data.replace("-t͡ʃ-w", "-t͡ʃʷ")
data = data.replace("-ʃː-w", "-ʃːʷ")
data = data.replace("-x-w", "-xʷ")
data = data.replace("-ʃː'-w", "-ʃː'ʷ")
data = data.replace("-d-w", "-dʷ")
data = data.replace("-ʒ-w", "-ʒʷ")
data = data.replace("-s-w", "-sʷ")
data = data.replace("-sː-w", "-sːʷ")
data = data.replace("-kː'-w", "-kː'ʷ")
data = data.replace("-sː'-w", "-sː'ʷ")
data = data.replace("-χ-w", "-χʷ")
data = data.replace("-z-w", "-zʷ")
data = data.replace("-r-w", "-rʷ")
data = data.replace("-t-w", "-tʷ")
data = data.replace("-l-w", "-lʷ")
data = data.replace("-n-w", "-nʷ")
data = data.replace("-t͡s'-w", "-t͡s'ʷ")

data = data.replace('͡', '')

# %%
words = data.split(' ')

# %%
words[2].split('-')
# Out:
# ['', 'h', 'a', "c'", 'a', 'r', 'a', 'l', 'a', 'ɬ', 'o', 'b']

# %%
type_freq = {}
stop = ['', '\n']
for word in words:
    frags = word.split('-')
    for f in frags:
        if f not in stop:
            if f in type_freq.keys():
                type_freq[f] += 1
            else:
                type_freq[f] = 1

# %%
type_f = []
type_sum = sum(type_freq.values())
for i in type_freq.values():
    type_f.append(i/type_sum)

# %%
import pandas as pd
df = pd.DataFrame()
df['segment'] = type_freq.keys()
df['text_value'] = type_freq.values()
df['text_frequency'] = type_f

# %%
list(df['segment'])
# Out:
# ["k'ʷ",
#  'a',
#  'n',
#  'ɬː',
#  'i',
#  's',
#  't',
#  'o',
#  'r',
#  'j',
#  'h',
#  "c'",
#  'l',
#  'ɬ',
#  'b',
#  'uː',
#  'w',
#  'e',
#  'k',
#  'u',
#  "k'",
#  'χ',
#  'm',
#  'sː',
#  'd',
#  "tʃ'",
#  'dʒ',
#  'p',
#  'ã',
#  'ʃ',
#  'tʃ',
#  "tɬ'",
#  "q'",
#  'ʃː',
#  'ʕ',
#  'eː',
#  'oː',
#  'ʃːʷ',
#  "t'",
#  'aː',
#  'ʒ',
#  'ħ',
#  'c',
#  'kʷ',
#  "s'",
#  'g',
#  'q',
#  'χː',
#  'iː',
#  'ũ',
#  "'",
#  'ʔ',
#  'ʁ',
#  'z',
#  'ãː',
#  'hʷ',
#  "tʃ'ʷ",
#  'χʷ',
#  "ʃ'",
#  'tʷ',
#  'ẽː',
#  'dʷ',
#  'tʃʷ',
#  'sːʷ',
#  'ĩ',
#  'rʷ',
#  "l'",
#  'ĩː',
#  'f',
#  'x',
#  'ʁʷ',
#  'sʷ',
#  'ʒʷ',
#  'nʷ',
#  'õː',
#  'tsː',
#  'ũː',
#  'χːʷ']

# %%
df.to_csv('bagv_text_res.csv')
